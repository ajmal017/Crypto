# %%
from modules import Kraken

# %%
constructor = Kraken(pair = 'ETH/EUR', api_key_file = 'kraken.key', minimum_fund=1000)

# %%
constructor.live_pattern(interval_ssl = 60, bars_ssl = 100, period_ssl = 10, 
                         interval_ema = 5, bars_ema = 200, period_ema = 50)
# Out:
# ------------------------------------------------------------------------
# starting 2020-09-19 02:50:00 5min candle
# 2020-09-19 02:00:00 hourly candle in progress
# we are in bearish pattern...its a sell
# -------------------------------------------------
# price: 322.57
# -------------------------------------------------
# closing price set to 321.60229
# the asset is not in the balance
# ------------------------------------------------------------------------
# starting 2020-09-19 02:55:00 5min candle
# 2020-09-19 02:00:00 hourly candle in progress
# we are in bearish pattern...its a sell
# -------------------------------------------------
# price: 322.09
# -------------------------------------------------
# closing price set to 321.12372999999997
# the asset is not in the balance
# ------------------------------------------------------------------------
# starting 2020-09-19 03:00:00 5min candle
# 2020-09-19 03:00:00 hourly candle in progress
# ...
